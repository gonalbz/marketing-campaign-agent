# %%
import sys
import pprint

sys.path.append('../')

from src.graph import graph

graph

# %%
thread = {"configurable": {"thread_id": "1"}}
result = graph.invoke(
    {
        "initial_request": "I want to plan a marketing campaign to sell my new electric car.",
    },
    thread
)

pprint.pprint(result['final_report'])
# Out:
# {'initial_request': 'I want to plan a marketing campaign to sell my new electric car.', 'search_queries': ['electric car marketing campaign strategies', 'target audience for electric cars', 'effective advertising channels for electric vehicles', 'government incentives for electric car purchases', 'consumer perception of electric car brands'], 'search_results': ['In the rapidly evolving landscape of electric vehicle marketing, seizing opportunities and overcoming challenges is paramount. As the market surges forward, brands and agencies have a unique chance to shape the future of automotive marketing. By addressing range anxiety, staying abreast of regulations, and emphasizing the growth of charging infrastructure, digital marketing professionals can', "Explore the innovative marketing approaches employed by automakers to promote electric vehicles and connect with environmentally-conscious consumers. Discover how electric car advertising is reshaping the automotive industry's approach
# ...
