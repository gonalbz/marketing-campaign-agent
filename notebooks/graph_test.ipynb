# %%
import sys
import pprint

sys.path.append('../')

from src.graph import graph

graph
# Out:
# ---------------------------------------------------------------------------
# DefaultCredentialsError                   Traceback (most recent call last)
# Cell In[4], line 6
#       2 import pprint
#       4 sys.path.append('../')
# ----> 6 from src.graph import graph
#       8 graph
#
# File ~/Documents/github/marketing-campaign-agent/notebooks/../src/graph.py:12
#       8 from langchain_core.messages import AnyMessage, SystemMessage, HumanMessage, AIMessage, ChatMessage
#      11 # define model to use
# ---> 12 model = init_chat_model(
#      13     "gemini-2.0-flash",
#      14     model_provider="google_genai",
#      15     temperature=0,
#      16 )
#      18 # define tool(s) that are available to use
#      19 tavily = TavilySearch(
#      20     max_results=settings.MAX_SEARCH_RESULTS_PER_QUESTION,
#      21     topic="general",
#      22 )
#
# File ~/Documents/github/marketing-campaign-agent/.venv/lib/python3.13/site-packages/langchain/chat_models/base.py:322, in init_chat_model(model, model_provider, configurable_fields, config_prefix, **kwargs)
#     315     warnings.warn(
#     316         f"{config_prefix=} has been set but no fields are configurable. Set "
#     317         f"`configurable_fields=(...)` to specify the model params that are "
#     318         f"configurable."
#     319     )
#     321 if not configurable_fields:
# --> 322     return _init_chat_model_helper(
#     323         cast(str, model), model_provider=model_provider, **kwargs
#     324     )
#     325 else:
#     326     if model:
#
# File ~/Documents/github/marketing-campaign-agent/.venv/lib/python3.13/site-packages/langchain/chat_models/base.py:375, in _init_chat_model_helper(model, model_provider, **kwargs)
#     372     _check_pkg("langchain_google_genai")
#     373     from langchain_google_genai import ChatGoogleGenerativeAI
# --> 375     return ChatGoogleGenerativeAI(model=model, **kwargs)
#     376 elif model_provider == "fireworks":
#     377     _check_pkg("langchain_fireworks")
#
# File ~/Documents/github/marketing-campaign-agent/.venv/lib/python3.13/site-packages/langchain_google_genai/chat_models.py:1179, in ChatGoogleGenerativeAI.__init__(self, **kwargs)
#    1172         suggestion = (
#    1173             f" Did you mean: '{suggestions[0]}'?" if suggestions else ""
#    1174         )
#    1175         logger.warning(
#    1176             f"Unexpected argument '{arg}' "
#    1177             f"provided to ChatGoogleGenerativeAI.{suggestion}"
#    1178         )
# -> 1179 super().__init__(**kwargs)
#
# File ~/Documents/github/marketing-campaign-agent/.venv/lib/python3.13/site-packages/langchain_core/load/serializable.py:130, in Serializable.__init__(self, *args, **kwargs)
#     128 def __init__(self, *args: Any, **kwargs: Any) -> None:
#     129     """"""  # noqa: D419
# --> 130     super().__init__(*args, **kwargs)
#
#     [... skipping hidden 1 frame]
#
# File ~/Documents/github/marketing-campaign-agent/.venv/lib/python3.13/site-packages/langchain_google_genai/chat_models.py:1240, in ChatGoogleGenerativeAI.validate_environment(self)
#    1238         google_api_key = self.google_api_key
#    1239 transport: Optional[str] = self.transport
# -> 1240 self.client = genaix.build_generative_service(
#    1241     credentials=self.credentials,
#    1242     api_key=google_api_key,
#    1243     client_info=client_info,
#    1244     client_options=self.client_options,
#    1245     transport=transport,
#    1246 )
#    1247 self.async_client_running = None
#    1248 return self
#
# File ~/Documents/github/marketing-campaign-agent/.venv/lib/python3.13/site-packages/langchain_google_genai/_genai_extension.py:276, in build_generative_service(credentials, api_key, client_options, client_info, transport)
#     262 def build_generative_service(
#     263     credentials: Optional[credentials.Credentials] = None,
#     264     api_key: Optional[str] = None,
#    (...)    267     transport: Optional[str] = None,
#     268 ) -> v1betaGenerativeServiceClient:
#     269     config = _prepare_config(
#     270         credentials=credentials,
#     271         api_key=api_key,
#    (...)    274         client_info=client_info,
#     275     )
# --> 276     return v1betaGenerativeServiceClient(**config)
#
# File ~/Documents/github/marketing-campaign-agent/.venv/lib/python3.13/site-packages/google/ai/generativelanguage_v1beta/services/generative_service/client.py:697, in GenerativeServiceClient.__init__(self, credentials, transport, client_options, client_info)
#     688     transport_init: Union[
#     689         Type[GenerativeServiceTransport],
#     690         Callable[..., GenerativeServiceTransport],
#    (...)    694         else cast(Callable[..., GenerativeServiceTransport], transport)
#     695     )
#     696     # initialize with the provided callable or the passed in class
# --> 697     self._transport = transport_init(
#     698         credentials=credentials,
#     699         credentials_file=self._client_options.credentials_file,
#     700         host=self._api_endpoint,
#     701         scopes=self._client_options.scopes,
#     702         client_cert_source_for_mtls=self._client_cert_source,
#     703         quota_project_id=self._client_options.quota_project_id,
#     704         client_info=client_info,
#     705         always_use_jwt_access=True,
#     706         api_audience=self._client_options.api_audience,
#     707     )
#     709 if "async" not in str(self._transport):
#     710     if CLIENT_LOGGING_SUPPORTED and _LOGGER.isEnabledFor(
#     711         std_logging.DEBUG
#     712     ):  # pragma: NO COVER
#
# File ~/Documents/github/marketing-campaign-agent/.venv/lib/python3.13/site-packages/google/ai/generativelanguage_v1beta/services/generative_service/transports/grpc.py:234, in GenerativeServiceGrpcTransport.__init__(self, host, credentials, credentials_file, scopes, channel, api_mtls_endpoint, client_cert_source, ssl_channel_credentials, client_cert_source_for_mtls, quota_project_id, client_info, always_use_jwt_access, api_audience)
#     229             self._ssl_channel_credentials = grpc.ssl_channel_credentials(
#     230                 certificate_chain=cert, private_key=key
#     231             )
#     233 # The base transport sets the host, credentials and scopes
# --> 234 super().__init__(
#     235     host=host,
#     236     credentials=credentials,
#     237     credentials_file=credentials_file,
#     238     scopes=scopes,
#     239     quota_project_id=quota_project_id,
#     240     client_info=client_info,
#     241     always_use_jwt_access=always_use_jwt_access,
#     242     api_audience=api_audience,
#     243 )
#     245 if not self._grpc_channel:
#     246     # initialize with the provided callable or the default channel
#     247     channel_init = channel or type(self).create_channel
#
# File ~/Documents/github/marketing-campaign-agent/.venv/lib/python3.13/site-packages/google/ai/generativelanguage_v1beta/services/generative_service/transports/base.py:100, in GenerativeServiceTransport.__init__(self, host, credentials, credentials_file, scopes, quota_project_id, client_info, always_use_jwt_access, api_audience, **kwargs)
#      96     credentials, _ = google.auth.load_credentials_from_file(
#      97         credentials_file, **scopes_kwargs, quota_project_id=quota_project_id
#      98     )
#      99 elif credentials is None and not self._ignore_credentials:
# --> 100     credentials, _ = google.auth.default(
#     101         **scopes_kwargs, quota_project_id=quota_project_id
#     102     )
#     103     # Don't apply audience if the credentials file passed from user.
#     104     if hasattr(credentials, "with_gdch_audience"):
#
# File ~/Documents/github/marketing-campaign-agent/.venv/lib/python3.13/site-packages/google/auth/_default.py:685, in default(scopes, request, quota_project_id, default_scopes)
#     677             _LOGGER.warning(
#     678                 "No project ID could be determined. Consider running "
#     679                 "`gcloud config set project` or setting the %s "
#     680                 "environment variable",
#     681                 environment_vars.PROJECT,
#     682             )
#     683         return credentials, effective_project_id
# --> 685 raise exceptions.DefaultCredentialsError(_CLOUD_SDK_MISSING_CREDENTIALS)
#
# DefaultCredentialsError: Your default credentials were not found. To set up Application Default Credentials, see https://cloud.google.com/docs/authentication/external/set-up-adc for more information.

# %%
thread = {"configurable": {"thread_id": "1"}}
result = graph.invoke(
    {
        "initial_request": "I want to plan a marketing campaign to sell my new electric car."
    },
    thread
)

pprint.pprint(result)
# Out:
# {'initial_request': 'I want to plan a marketing campaign to sell my new '
#                     'electric car.',
#  'search_queries': ['electric car marketing campaign strategies',
#                     'target audience for electric cars',
#                     'effective advertising channels for electric vehicles',
#                     'incentives for buying electric cars',
#                     'common concerns of electric car buyers'],
#  'search_results': ['Convenience and Accessibility: Marketing strategies '
#                     'showcase the ease of access to charging infrastructure, '
#                     'which is essential in promoting electric cars as '
#                     'practical options for daily use. Range Anxiety '
#                     'Mitigation: Overcoming range anxiety concerns is a '
#                     'central marketing theme, often using statistics and '
#                     'real-world examples to illustrate the',
#                     'Electric Vehicle (EV) Marketing: Strategies & Challenges '
#                     'By tailoring marketing efforts to the unique stages of '
#                     'the EV buying journey, digital marketers can effectively '
#                     'guide potential buyers toward embracing electric vehicle '
#                     'ownership. From educating potential buyers to driving '
#                     'local engagement, successful electric vehicle (EV) '
#                     'marketing demands a tailored approach at every stage. '
#                     'Tier 1 automotive marketing in the electric vehicle (EV) '
#                     'space requires a strategic approach tailored to potential '
#                     'EV buyers’ unique needs and considerations. Tier 2 '
#                     'automotive marketing for electric vehicles (EVs) is '
#                     'regionally focused, targeting potential buyers in the '
#                     'consideration stage. Tier 3 automotive marketing for '
#                     'electric vehicles (EVs) is hyper-localized, focusing on '
#                     'driving consumers to the dealer lot during the final '
#                     'stages of the purchase journey.',
#                     'Marketing Strategies for the Booming Electric Vehicle '
#                     'Industry Insights The Ever-Evolving Landscape of the '
#                     'Electric Vehicle Industry: A Sneak Peek As the world '
#                     'accelerates towards a more eco-conscious future, the '
#                     'electric vehicle (EV) market is experiencing '
#                     'unprecedented growth. In this critical transition, our '
#                     'marketing strategies for the booming electric vehicle '
#                     'industry require reinvention to propel this burgeoning '
#                     'sector. Why Traditional Marketing Strategies Fail in the '
#                     'EV Sector The electric vehicle industry challenges the '
#                     'traditional automotive market with its unique business '
#                     'models, market demands, and consumer expectations. The '
#                     'imperative for sustainability and innovation in the EV '
#                     'sector renders outdated marketing tools ineffective. In '
#                     'the rapidly evolving Electric Vehicle Market Expansion, '
#                     'potential customers often begin their journey online.',
#                     'The target market for electric cars is diverse, spanning '
#                     'environmentally conscious consumers, tech-savvy early '
#                     'adopters, urban commuters, high-income professionals, and '
#                     'budget-conscious buyers. Each group has distinct '
#                     "motivations, whether it's reducing their carbon "
#                     'footprint, embracing cutting-edge technology, or seeking '
#                     'long-term cost',
#                     '[cbm_blg_rlnkng]Understanding customer demographics and '
#                     'target market segmentation is essential when marketing '
#                     'electric vehicles (EVs). With the rapidly growing '
#                     'popularity of EVs, it is crucial for businesses to '
#                     'identify and cater to specific consumer groups who are '
#                     'most likely to purchase these environmentally friendl',
#                     "To better understand Tesla's target audience, we can "
#                     'examine various demographics and psychographic factors: '
#                     '... In the U.S. electric vehicle market, there are '
#                     "various automakers striving to compete with Tesla's "
#                     "dominance. General Motors: Labelled as Tesla's biggest "
#                     'competitor, GM has plans to launch 30 new electric '
#                     'vehicles by 2025',
#                     'Electric vehicle (EV) sales grew by 66% year-over-year in '
#                     'Q1 2023 as consumer demand for more sustainable vehicles '
#                     'increases and federal tax credits incentivize shoppers. '
#                     'Translate demand for EVs into sales with an advertising '
#                     'strategy for shoppers at all stages of the buying '
#                     'journey. Demand-based Advertising for EVs',
#                     'Much like how conversational AI has revolutionized '
#                     'medical offices, innovative marketing approaches are now '
#                     'reshaping how electric vehicles are presented to '
#                     'potential buyers, combining technological advancement '
#                     'with human-centered messaging. Smart EV marketers are now '
#                     'using AI conversation tools to analyze and amplify these '
#                     'authentic customer stories across digital channels, '
#                     'creating compelling narratives that resonate with '
#                     'prospective buyers. Many EV manufacturers are now '
#                     'implementing AI sales generators that analyze customer '
#                     'data to create hyper-personalized marketing messages and '
#                     'offers that address individual needs and usage patterns. '
#                     'Many manufacturers now use AI customer service solutions '
#                     'to provide 24/7 support to EV owners, ensuring questions '
#                     'are answered promptly regardless of time or day. '
#                     'Callin.io provides AI-powered phone agents that can '
#                     'handle inquiries, schedule test drives, and provide '
#                     'information about electric vehicles with the natural '
#                     'conversation flow customers expect.',
#                     'Electric Vehicle (EV) Marketing: Strategies & Challenges '
#                     'By tailoring marketing efforts to the unique stages of '
#                     'the EV buying journey, digital marketers can effectively '
#                     'guide potential buyers toward embracing electric vehicle '
#                     'ownership. From educating potential buyers to driving '
#                     'local engagement, successful electric vehicle (EV) '
#                     'marketing demands a tailored approach at every stage. '
#                     'Tier 1 automotive marketing in the electric vehicle (EV) '
#                     'space requires a strategic approach tailored to potential '
#                     'EV buyers’ unique needs and considerations. Tier 2 '
#                     'automotive marketing for electric vehicles (EVs) is '
#                     'regionally focused, targeting potential buyers in the '
#                     'consideration stage. Tier 3 automotive marketing for '
#                     'electric vehicles (EVs) is hyper-localized, focusing on '
#                     'driving consumers to the dealer lot during the final '
#                     'stages of the purchase journey.',
#                     'Redding Electric Utility\xa0(REU) provides a residential '
#                     'EV rebate program, giving income-qualifying customers a '
#                     '$3,000 voucher when they purchase or lease a qualifying '
#                     'new electric vehicle or PHEV from a participating '
#                     'dealership. DTE Energy\xa0provides a $500 Charging '
#                     'Forward Rebate for customers who buy or lease an electric '
#                     'vehicle, install a qualified Level 2 charger, and enroll '
#                     'in the discounted time-of-use program. Great Lakes Energy '
#                     'gives an $800 rebate to residential customers for '
#                     'purchasing a networked Level 2 electric vehicle charging '
#                     'station and an additional $500 for purchasing or leasing '
#                     'a new EV. Atlantic City Electric offers residential '
#                     'customers rebates of up to $1,000 for installing a Level '
#                     '2 EV charging station and provides a time-of-use rate to '
#                     'residential customers who own or lease EVs. New Mexico',
#                     'The U.S. government is putting increased weight into the '
#                     'shift, with the EPA releasing a full list of EVs eligible '
#                     "for tax incentives. We've done the due diligence of "
#                     "gathering each EV that's",
#                     'Credits for new clean vehicles purchased in 2023 or after '
#                     '| Internal Revenue Service 4.   Clean vehicle credits '
#                     '5.    Credits for new clean vehicles purchased in 2023 or '
#                     'after  Credits for new clean vehicles purchased in 2023 '
#                     'or after Clean vehicle credits If you place in service a '
#                     'new plug-in electric vehicle (EV) or fuel cell vehicle '
#                     '(FCV)in 2023 or after, you may qualify for a clean '
#                     'vehicle tax credit. For more information on how to '
#                     'qualify see Publication 5866, New Clean Vehicle Tax '
#                     'Credit Checklist PDF"). Find information on credits '
#                     'forused clean vehicles,qualified commercial clean '
#                     'vehiclesandnew plug-in EVs purchased before 2023. To '
#                     'claim the credit, fileForm 8936, Clean Vehicle '
#                     'Creditswith your tax return. Publication 5866, NEW Clean '
#                     'Vehicle Tax Credit Checklist PDF") Used Clean Vehicle '
#                     'Credit',
#                     "However, the widespread adoption of EV's is not without "
#                     'its challenges. EV owners often face a laundry list of '
#                     'problems that can impact their ownership experience. '
#                     "Let's take a look at the 20 most common electric vehicle "
#                     'issues owners complain about:',
#                     'Combined, electric cars, trucks, SUVs, and even '
#                     'commercial vehicles made up approximately 10% of U.S. car '
#                     'sales in 2022. In the same year, a Consumer Reports '
#                     'survey revealed that 71% of American respondents '
#                     'expressed interest in leasing or buying an EV.',
#                     'Many countries around the world are making and '
#                     'implementing policies banning gas-powered vehicles in the '
#                     'near future as a step to reduce damage to the climate. '
#                     "Below you'll find 11 common issues with electric vehicles "
#                     'and how to overcome them.']}
